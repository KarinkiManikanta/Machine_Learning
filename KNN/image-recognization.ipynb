# %%
import numpy as np
import matplotlib.pyplot as plt


Data = plt.imread('Data.png')
plt.imshow(Data)


eyes =Data[145:170,210:310] 
#plt.imshow(eyes)


np.savetxt('Data.csv',eyes.ravel())
plt.show()
