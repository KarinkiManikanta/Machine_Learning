# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path="/home/hemanth/Documents/DeepLearning/MLP/buddha-statue-hyderabadhyderabadindia-260nw-1366155431.jpg"

# %%
img_red=plt.imread(path)
img_red
# Out:
# array([[[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 15,  33,  88],
#         ...,
#         [135, 156, 192],
#         [138, 160, 196],
#         [137, 158, 194]],
#
#        [[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 15,  33,  88],
#         ...,
#         [138, 159, 198],
#         [140, 161, 200],
#         [138, 159, 198]],
#
#        [[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 16,  34,  89],
#         ...,
#         [133, 153, 199],
#         [138, 158, 202],
#         [138, 158, 202]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_red.shape
# Out:
# (280, 390, 3)

# %%
img_red.size
# Out:
# 327600

# %%
img_red.ndim
# Out:
# 3

# %%
plt.figure(figsize=(30,15))
plt.imshow(img_red)

# %%
# by using pillow library
from PIL import Image
img=Image.open('/home/hemanth/Documents/DeepLearning/MLP/buddha-statue-hyderabadhyderabadindia-260nw-1366155431.jpg')

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=390x280 at 0x7F1D9E288310>

# %%
np.array(img)
# Out:
# array([[[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 15,  33,  88],
#         ...,
#         [135, 156, 192],
#         [138, 160, 196],
#         [137, 158, 194]],
#
#        [[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 15,  33,  88],
#         ...,
#         [138, 159, 198],
#         [140, 161, 200],
#         [138, 159, 198]],
#
#        [[ 15,  33,  88],
#         [ 15,  33,  88],
#         [ 16,  34,  89],
#         ...,
#         [133, 153, 199],
#         [138, 158, 202],
#         [138, 158, 202]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
## By using Tensorflow

# %%
import tensorflow as tf
#from tensorflow.keras import keras
img1=tf.keras.preprocessing.image._load_img(path)
img1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4948fab8df46> in <module>
#       1 import tensorflow as tf
#       2 #from tensorflow.keras import keras
# ----> 3 img1=tf.keras.preprocessing.image._load_img(path)
#       4 img1
#
# AttributeError: module 'tensorflow.keras.preprocessing.image' has no attribute '_load_img'

# %% [markdown]
# ### Data Argumentation
# ## To avoid overfitting process in image dataset
# ## Zoom the image
# ## shift (Vertial/ Horizontal)
# ## Resize
# ## Rotation

# %%
### Multiple Load images
directory='/home/hemanth/Documents/DeepLearning/image/'

# %%
Data=tf.keras.preprocessing.image_dataset_from_directory(directory)
# Out:
# Found 165 files belonging to 3 classes.

# %%
Data
# Out:
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import pathlib
import os

# %%
dataset_url="https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
dataset_url
# Out:
# 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz'

# %%
data_dir=tf.keras.utils.get_file(origin=dataset_url,fname='flower_photos',untar=True)

# %%
data_dir=pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('/home/hemanth/.keras/datasets/flower_photos')

# %%
image_count=len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
tulips=list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213 at 0x7F9ECFFB0A90>

# %%
daisy=list(data_dir.glob('daisy/*'))
PIL.Image.open(str(daisy[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x239 at 0x7F9ECFF1BD90>

# %%
roses=list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=161x240 at 0x7F9ECFF1BA30>

# %%
batch_size=32
img_height=250
img_width=250

# %%
train_ds=tf.keras.preprocessing.image_dataset_from_directory(
                                                            data_dir,
                                                            validation_split=0.2,
                                                            subset="training",
                                                            seed=123,
                                                            image_size=(img_height,img_width),
                                                            batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
train_ds.class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
val_ds=tf.keras.preprocessing.image_dataset_from_directory(
                                                            data_dir,
                                                            validation_split=0.2,
                                                            subset="training",
                                                            seed=123,
                                                            image_size=(img_height,img_width),
                                                            batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds.class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
class_names=train_ds.class_names

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(10,10))
for images, lables in train_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[lables[i]])
    plt.axis('off')

# %%
for images_batch,labels_batch in train_ds:
    print(images_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 250, 250, 3)
# (32,)

# %% [markdown]
# ## Data Normalization In Tensorflow

# %%
normalization_layer=tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalizes_ds=train_ds.map(lambda x,y:(normalization_layer(x),y))
images_batch,labels_batch=next(iter(normalizes_ds))

# %%
first_image=images_batch[0]

# %%
np.min(first_image),np.max(first_image)
# Out:
# (0.0, 0.9639371)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow import keras
from tensorflow.keras import layers
num_classes = 5

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 92/92 [==============================] - 172s 2s/step - loss: 1.3321 - accuracy: 0.4384 - val_loss: 1.1012 - val_accuracy: 0.5698
# Epoch 2/3
# 92/92 [==============================] - 171s 2s/step - loss: 1.0636 - accuracy: 0.5841 - val_loss: 0.9404 - val_accuracy: 0.6410
# Epoch 3/3
# 92/92 [==============================] - 159s 2s/step - loss: 0.9153 - accuracy: 0.6352 - val_loss: 0.7213 - val_accuracy: 0.7384

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'/home/hemanth/.keras/datasets/flower_photos/sunflowers/265422922_bbbde781d2_m.jpg'
# b'/home/hemanth/.keras/datasets/flower_photos/daisy/3098641292_76c908ba1f_n.jpg'
# b'/home/hemanth/.keras/datasets/flower_photos/dandelion/5675705011_82729927ca_n.jpg'
# b'/home/hemanth/.keras/datasets/flower_photos/sunflowers/4847062576_bae870479c_n.jpg'
# b'/home/hemanth/.keras/datasets/flower_photos/sunflowers/3848405800_8eea982c40.jpg'

# %%
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['daisy' 'dandelion' 'roses' 'sunflowers' 'tulips']

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 2936
# 734

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (250, 250, 3)
# Label:  3

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].numpy().astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 92/92 [==============================] - 141s 2s/step - loss: 0.7746 - accuracy: 0.7054 - val_loss: 0.7026 - val_accuracy: 0.7098
# Epoch 2/3
# 92/92 [==============================] - 152s 2s/step - loss: 0.5265 - accuracy: 0.8007 - val_loss: 0.7909 - val_accuracy: 0.6935
# Epoch 3/3
# 92/92 [==============================] - 132s 1s/step - loss: 0.3015 - accuracy: 0.8948 - val_loss: 0.9654 - val_accuracy: 0.6703

# %%
(train_ds, val_ds, test_ds), metadata = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)
# Out:
# ...
# WARNING:absl:Dataset tf_flowers is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead pass
# `try_gcs=True` to `tfds.load` or set `data_dir=gs://tfds-data/datasets`.
# ...
# Dataset tf_flowers downloaded and prepared to /home/hemanth/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.

# %%
num_classes = metadata.features['label'].num_classes
print(num_classes)
# Out:
# 5

# %%
get_label_name = metadata.features['label'].int2str

image, label = next(iter(train_ds))
_ = plt.imshow(image)
_ = plt.title(get_label_name(label))

# %%
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)
test_ds = configure_for_performance(test_ds)
