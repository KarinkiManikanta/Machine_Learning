# %%
import numpy as np
import pandas as pd
import pandas_profiling 
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Temperature_Pressure_Dataset.csv')

# %%
data
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sno          6 non-null      int64
#  1   Temperature  6 non-null      int64
#  2   Pressure     6 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 272.0 bytes

# %%
data.tail()
# Out:
#    sno  Temperature  Pressure
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
pandas_profiling.ProfileReport(data)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
sns.pairplot(data)

# %%
x=data.iloc[:,1:2]
x
# Out:
#    Temperature
# 0            0
# 1           20
# 2           40
# 3           60
# 4           80
# 5          100

# %%
y=data.iloc[:,2]

# %%
lin=LinearRegression()

# %%
lin.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
lin.score(x,y)
# Out:
# 0.6903499726039811

# %%
lin.coef_
# Out:
# array([0.002342])

# %%
lin.intercept_
# Out:
# -0.05086666666666673

# %%
#visualising the linear regrssion results
plt.scatter(x,y,color='blue')
plt.plot(x,lin.predict(x),color='gray')
plt.title('Linear Regrssion')
plt.xlabel('temperature')
plt.ylabel('pressure')
plt.show()

# %%
#fitting polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=6)
x_poly=poly.fit_transform(x)
poly.fit(x_poly,y)
# Out:
# PolynomialFeatures(degree=6, include_bias=True, interaction_only=False,
#                    order='C')

# %%
lin2=LinearRegression()
lin2.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#visualising the polynomial regression results
plt.figure(figsize=(20,9))
plt.scatter(x,y,color='blue')
plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.xlabel('Temperature')
plt.ylabel('pressure')
plt.show()

# %%
x=np.arange(-5.0,5.0,0.1)
print("size of x data is:",x.size)
# Out:
# size of x data is: 100

# %%
## you can adjust the slope and intercept to verity the changes in the graph
y=2*(x)+3
y_noise=0.2*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
## you can adjust the slope and intercept to verity the changes in the graph
y=1*(x**3)+1*(x**2)+1*x+3
y_noise=5*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
## you can adjust the slope and intercept to verity the changes in the graph
y=np.log(1*(x**3)+1*(x**2)+1*x+3)
y_noise=0.9*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
## you can adjust the slope and intercept to verity the changes in the graph
y=np.power(x,2)
y_noise=5*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
x=np.linspace(-9,9,400)
y=np.linspace(-5,5,400)
x,y=np.meshgrid(x,y)

# %%
def axes():
    plt.figure(figsize=(16,9))
    plt.axvline(0,alpha=0.9)
    plt.axvline(0,alpha=0.9)

# %%
a=0.2
b=0.1
axes()
plt.contour(x,y,(x**2/a**2-y**2/b**2),[1],colors='y')
plt.show()

# %%
axes()
plt.contour(x,y,(y**2-4*a*x),[0],colors='y')

# %%
## you can adjust the slope and intercept to verity the changes in the graph
x=np.arange(-5.0,5.0,0.1)
y=np.exp(x)
y_noise=5*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
## you can adjust the slope and intercept to verity the changes in the graph
x=np.arange(-5.0,5.0,0.1)
y=np.log(x)
y_noise=0.2*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
## you can adjust the slope and intercept to verity the changes in the graph
x=np.arange(-5.0,5.0,0.1)
y=1-4/(1)
y_noise=0.2*np.random.normal(size=x.size)
ydata=y+y_noise
plt.figure(figsize=(20,9))
plt.scatter(x,ydata)
plt.plot(x,y,'r')
#plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-14a54496a111> in <module>
#       5 ydata=y+y_noise
#       6 plt.figure(figsize=(20,9))
# ----> 7 plt.scatter(x,ydata,'bo')
#       8 plt.plot(x,y,)
#       9 #plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
# ...
