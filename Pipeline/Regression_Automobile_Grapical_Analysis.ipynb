# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hemanth/Downloads/auto_clean.csv")

# %%
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
data.tail()
# Out:
#      symboling  normalized-losses   make aspiration num-of-doors body-style  \
# 196         -1                 95  volvo        std         four      sedan
# 197         -1                 95  volvo      turbo         four      sedan
# 198         -1                 95  volvo        std         four      sedan
# 199         -1                 95  volvo      turbo         four      sedan
# 200         -1                 95  volvo      turbo         four      sedan
#
#     drive-wheels engine-location  wheel-base    length  ...  \
# 196          rwd           front       109.1  0.907256  ...
# 197          rwd           front       109.1  0.907256  ...
# 198          rwd           front       109.1  0.907256  ...
# 199          rwd           front       109.1  0.907256  ...
# 200          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
data.shape
# Out:
# (201, 29)

# %%
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
data['horsepower-binned'].unique()
# Out:
# array(['Medium', 'Low', 'High', nan], dtype=object)

# %%
dataset=data.dropna()

# %%
dataset.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          196 non-null    int64
#  1   normalized-losses  196 non-null    int64
#  2   make               196 non-null    object
#  3   aspiration         196 non-null    object
#  4   num-of-doors       196 non-null    object
#  5   body-style         196 non-null    object
#  6   drive-wheels       196 non-null    object
#  7   engine-location    196 non-null    object
#  8   wheel-base         196 non-null    float64
#  9   length             196 non-null    float64
#  10  width              196 non-null    float64
#  11  height             196 non-null    float64
#  12  curb-weight        196 non-null    int64
#  13  engine-type        196 non-null    object
#  14  num-of-cylinders   196 non-null    object
#  15  engine-size        196 non-null    int64
# ...

# %%
dataset.describe().T
# Out:
#                    count          mean          std          min          25%  \
# symboling          196.0      0.801020     1.230467    -2.000000     0.000000
# normalized-losses  196.0    121.428571    32.149650    65.000000    97.250000
# wheel-base         196.0     98.852041     6.118651    86.600000    94.500000
# length             196.0      0.837183     0.059556     0.678039     0.799135
# width              196.0      0.914846     0.029181     0.837500     0.889931
# height             196.0     53.882143     2.365031    48.800000    52.000000
# curb-weight        196.0   2551.500000   513.797670  1488.000000  2145.000000
# engine-size        196.0    126.969388    38.807468    61.000000    98.000000
# bore               196.0      3.329643     0.271071     2.540000     3.150000
# stroke             196.0      3.259439     0.318079     2.070000     3.110000
# compression-ratio  196.0     10.173061     4.053371     7.000000     8.500000
# ...

# %%
dataset['fuel-system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', 'idi', 'spdi'], dtype=object)

# %%
dataset['horsepower-binned'].unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
dataset['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'eight'], dtype=object)

# %%
dataset['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'ohcf'], dtype=object)

# %%
dataset['engine-location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
dataset['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
dataset['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
dataset['num-of-doors'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
dataset['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
dataset['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
dataset.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.453423   -0.533112 -0.359883
# normalized-losses   0.453423           1.000000   -0.046971  0.027234
# wheel-base         -0.533112          -0.046971    1.000000  0.876945
# length             -0.359883           0.027234    0.876945  1.000000
# width              -0.242821           0.090056    0.821427  0.857249
# height             -0.539407          -0.362499    0.607417  0.522367
# curb-weight        -0.226121           0.107034    0.790205  0.882091
# engine-size        -0.055329           0.147862    0.592517  0.698626
# bore               -0.142125          -0.030152    0.493941  0.608496
# stroke             -0.013520           0.056054    0.163725  0.136850
# compression-ratio  -0.180275          -0.112288    0.248383  0.156926
# horsepower          0.090778           0.226654    0.381984  0.583073
# ...

# %%
dataset['price'].value_counts()
# Out:
# 8845.0     2
# 18150.0    2
# 8495.0     2
# 6229.0     2
# 13499.0    2
#           ..
# 9295.0     1
# 15580.0    1
# 6377.0     1
# 30760.0    1
# 18920.0    1
# Name: price, Length: 181, dtype: int64

# %% [markdown]
# ### Graphical Analysis

# %%
sns.regplot(x='width',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='width', ylabel='price'>

# %%
sns.regplot(x='height',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='height', ylabel='price'>

# %%
sns.regplot(x='curb-weight',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='price'>

# %%
sns.regplot(x='bore',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='bore', ylabel='price'>

# %%
sns.regplot(x='horsepower',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
sns.regplot(x='city-mpg',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='price'>

# %%
sns.regplot(x='highway-mpg',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
dataset[['width','horsepower','curb-weight','city-mpg','highway-mpg','wheel-base','engine-size','price']].corr()
# Out:
#                 width  horsepower  curb-weight  city-mpg  highway-mpg  \
# width        1.000000    0.604099     0.862835 -0.639692    -0.684550
# horsepower   0.604099    1.000000     0.750749 -0.838567    -0.815187
# curb-weight  0.862835    0.750749     1.000000 -0.766146    -0.808146
# city-mpg    -0.639692   -0.838567    -0.766146  1.000000     0.971016
# highway-mpg -0.684550   -0.815187    -0.808146  0.971016     1.000000
# wheel-base   0.821427    0.381984     0.790205 -0.496565    -0.566948
# engine-size  0.739543    0.825377     0.858968 -0.712693    -0.734062
# price        0.744176    0.802040     0.828483 -0.692550    -0.707466
#
#              wheel-base  engine-size     price
# width          0.821427     0.739543  0.744176
# horsepower     0.381984     0.825377  0.802040
# curb-weight    0.790205     0.858968  0.828483
# city-mpg      -0.496565    -0.712693 -0.692550
# highway-mpg   -0.566948    -0.734062 -0.707466
# wheel-base     1.000000     0.592517  0.591956
# ...

# %% [markdown]
# ## Analysing categorical features using boxplot of 'seaborn'

# %%
sns.boxplot(x='aspiration',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='price'>

# %%
sns.boxplot(x='num-of-doors',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='num-of-doors', ylabel='price'>

# %%
sns.boxplot(x='body-style',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
df1=dataset['engine-location'].value_counts().to_frame()
df1.columns=['value_counts']
df1.index.name='engine-location'

# %%
df1
# Out:
#                  value_counts
# engine-location
# front                     193
# rear                        3

# %% [markdown]
# ### Analysis by Grouping Data

# %%
df1=dataset[['engine-location','price']].groupby('engine-location')
df1.get_group('front').head()
# Out:
#   engine-location    price
# 0           front  13495.0
# 1           front  16500.0
# 2           front  16500.0
# 3           front  13950.0
# 4           front  17450.0

# %%
dataset.groupby('engine-location').mean()['price'].to_frame()
# Out:
#                         price
# engine-location
# front            12761.497409
# rear             34528.000000

# %%
df1=dataset[['drive-wheels','body-style','price']].groupby(['drive-wheels','body-style'],as_index=False).mean()
df1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14714.285714
# 11          rwd        sedan  21303.600000
# 12          rwd        wagon  16994.222222

# %%
sns.pairplot(dataset,hue='price')
# Out:
# /home/hemanth/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/hemanth/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/hemanth/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/hemanth/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/hemanth/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data1=dataset[['width','horsepower','curb-weight','city-mpg','highway-mpg','wheel-base','engine-size','price']]

# %%
sns.pairplot(data1)

# %%
data1.head()
# Out:
#       width  horsepower  curb-weight  city-mpg  highway-mpg  wheel-base  \
# 0  0.890278       111.0         2548        21           27        88.6
# 1  0.890278       111.0         2548        21           27        88.6
# 2  0.909722       154.0         2823        19           26        94.5
# 3  0.919444       102.0         2337        24           30        99.8
# 4  0.922222       115.0         2824        18           22        99.4
#
#    engine-size    price
# 0          130  13495.0
# 1          130  16500.0
# 2          152  16500.0
# 3          109  13950.0
# 4          136  17450.0

# %%
from sklearn.model_selection import train_test_split

# %%
x=data1.drop(['price'],axis=1)
x.head()
# Out:
#       width  horsepower  curb-weight  city-mpg  highway-mpg  wheel-base  \
# 0  0.890278       111.0         2548        21           27        88.6
# 1  0.890278       111.0         2548        21           27        88.6
# 2  0.909722       154.0         2823        19           26        94.5
# 3  0.919444       102.0         2337        24           30        99.8
# 4  0.922222       115.0         2824        18           22        99.4
#
#    engine-size
# 0          130
# 1          130
# 2          152
# 3          109
# 4          136

# %%
y=data1['price']
y.tail()
# Out:
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, dtype: float64

# %%
# Split-out validation dataset
from sklearn import model_selection
validation_size = 0.20
seed = 7

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(x, y, test_size=validation_size, random_state=seed)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (156, 7)
# (40, 7)
# (156,)
# (40,)

# %%
x.shape
# Out:
# (196, 7)

# %%
y.shape
# Out:
# (196,)

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import model_selection

# %%
models = []
models.append(('LR', LinearRegression()))
models.append(('RIDGE', Ridge()))
models.append(('LASSO', Lasso()))
models.append(('ELN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('DT', DecisionTreeRegressor()))
models.append(('SVM', SVR()))
scoring = 'r2'

# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X_train, Y_train,  cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# /home/hemanth/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# /home/hemanth/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# LR: 0.760139 (0.072068)
# RIDGE: 0.754618 (0.069547)
# LASSO: 0.759359 (0.072418)
# ELN: 0.756309 (0.067833)
# KNN: 0.740582 (0.126564)
# DT: 0.851385 (0.082417)
# SVM: -0.133448 (0.058206)
# ...

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
# train the model
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)

#We now have a fit model, pass in our test data to the fitted model to make predictions with it.
predictions = model.predict(X_test)

#calculate the error
from sklearn.metrics import r2_score
r2_score(Y_test,predictions)
# Out:
# 0.8736249002051067
