# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling
import scipy as stats
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/KarinkiManikanta/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/FuelConsumption.csv')

# %%
data.isna().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
#import warnings
#warnings.filterwarning('ignore')

# %%
data.head(2)
# Out:
#    MODELYEAR   MAKE MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0       2014  ACURA   ILX      COMPACT         2.0          4          AS5
# 1       2014  ACURA   ILX      COMPACT         2.4          4           M6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221

# %%
data.tail(2)
# Out:
#       MODELYEAR   MAKE     MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 1065       2014  VOLVO  XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO  XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
data.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
data.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1067, step=1)

# %%
sns.pairplot(data)

# %%
pandas_profiling.ProfileReport(data)
# Out:
# /home/manikanta/.local/lib/python3.6/site-packages/pandas_profiling/model/correlations.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
df=data[['MODELYEAR', 'ENGINESIZE', 'CYLINDERS','FUELCONSUMPTION_CITY',
       'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
       'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS']]

# %%
sns.countplot(df['MODELYEAR'])

# %%
sns.lmplot(x='ENGINESIZE',y='CO2EMISSIONS',data=df)

# %%
sns.pairplot(df[['MODELYEAR', 'ENGINESIZE', 'CYLINDERS','FUELCONSUMPTION_CITY',
       'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
       'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS']],diag_kind='linear')

# %%
sns.boxplot(df['ENGINESIZE'])

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
for i in df.columns:
    sns.relplot(x=i,y='CO2EMISSIONS',data=df)

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(df,ax=ax,annot=True,linewidth=0.5)

# %%
x=df['ENGINESIZE']
y=df['CO2EMISSIONS']

# %%
with sns.axes_style('white'):
    sns.jointplot(x=x,y=y,kind='hex',color='y')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
x=df.drop('CO2EMISSIONS',axis=1)

# %%
y=df['CO2EMISSIONS']

# %%
X_traine,X_test,Y_traine,Y_test,=train_test_split(x,y)

# %%
X_traine.shape
# Out:
# (800, 7)

# %%
Y_traine.shape
# Out:
# (800,)

# %%
X_test.shape
# Out:
# (267, 7)

# %%
Y_test.shape
# Out:
# (267,)

# %%
train=pd.DataFrame(X_traine,Y_traine)
train
# Out:
#               MODELYEAR  ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# CO2EMISSIONS
# 232              2014.0         2.4        4.0                  10.0
# 258              2014.0         1.4        4.0                   8.7
# 232              2014.0         2.4        4.0                  10.0
# 177              2014.0         6.2        8.0                  19.7
# 207              2014.0         2.4        4.0                  11.5
# ...                 ...         ...        ...                   ...
# 271              2014.0         1.4        4.0                   9.4
# 380              2014.0         5.0        8.0                  22.1
# 227              2014.0         6.0        8.0                  22.1
# 242              2014.0         4.3        6.0                  14.2
# 256              2014.0         1.4        4.0                   8.7
#
#               FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# CO2EMISSIONS
# ...

# %%
train.to_csv('traine_FuelConsumption1.csv')

# %%
test=pd.DataFrame(X_test,Y_test)

# %%
test.to_csv('test_FuelConsumption.csv')

# %%
model=LinearRegression()

# %%
model.fit(X_traine,Y_traine)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([  0.        ,   9.74688683,   6.64829426, -15.64240698,
#         -7.83995675,  27.32599516,  -3.83208224])

# %%
model.intercept_
# Out:
# 252.5219665624903

# %%
train_score=np.round(model.score(X_traine,Y_traine)*100,2)

# %%
train_score
# Out:
# 88.47

# %%
test_score=np.round(model.score(X_test,Y_test)*100,2)
test_score
# Out:
# 90.28

# %%
New_predication = model.predict(X_test)

# %%
pd.DataFrame({'New_predication':New_predication,
             "ActualData":Y_test,
             "Error":Y_test-New_predication,
             "MSE":np.sqrt(np.mean(Y_test-New_predication))})
# Out:
# /home/manikanta/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.
#       New_predication  ActualData      Error  MSE
# 642        365.846538         342 -23.846538  NaN
# 792        190.871044         191   0.128956  NaN
# 723        208.479270         216   7.520730  NaN
# 371        344.253372         366  21.746628  NaN
# 290        326.565734         317  -9.565734  NaN
# ...               ...         ...        ...  ...
# 1026       216.974309         223   6.025691  NaN
# 843        287.316859         301  13.683141  NaN
# 172        264.611190         262  -2.611190  NaN
# 402        226.944653         165 -61.944653  NaN
# 589        216.570926         225   8.429074  NaN
#
# [267 rows x 4 columns]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
r2_score(Y_test,New_predication)
# Out:
# 0.9028105910442196

# %%
mean_squared_error(Y_test,New_predication)
# Out:
# 375.94459281388924

# %%
mean_absolute_error(Y_test,New_predication)
# Out:
# 13.113253008543237

# %%
from sklearn.model_selection import cross_val_score

# %%
cv = cross_val_score(model,X_traine,Y_traine,cv = 10)
cv
# Out:
# array([0.89032687, 0.87373211, 0.88991872, 0.87707968, 0.86608752,
#        0.88854429, 0.89615498, 0.86717078, 0.88479273, 0.87075963])

# %%
np.min(cv)
# Out:
# 0.8660875161881152

# %%
np.max(cv)
# Out:
# 0.8961549799251031

# %%
np.mean(cv)
# Out:
# 0.8804567310884808

# %%
plt.figure(figsize=(16,10))
plt.scatter(x,y)
plt.plot(x,model.intercept_+slope*x,'r')
plt.title("MLR for FuelConsumption")
plt.xlabel('MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
       'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
       'FUELCONSUMPTION_COMB_MPG')
plt.ylabel("CO2EMISSIONS")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-1850b46b9cd8> in <module>
#       1 plt.figure(figsize=(16,10))
# ----> 2 plt.scatter(x,y)
#       3 plt.plot(x,model.intercept_+slope*x,'r')
#       4 plt.title("MLR for FuelConsumption")
#       5 plt.xlabel('MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY',
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...
